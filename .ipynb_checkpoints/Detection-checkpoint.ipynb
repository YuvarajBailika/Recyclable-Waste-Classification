# %% [markdown]
# # Importing the Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ['TORCH_USE_CUDA_DSA'] = "1"

# %%
import torch
from IPython.display import Image
import shutil
import os
from random import choice

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
ML_Model = []
precision = []
recall = []
mAP = []

#function to call for storing the results
def storeResults(model, a,b,c):
    ML_Model.append(model)
    precision.append(round(a, 3))
    recall.append(round(b, 3))
    mAP.append(round(c, 3))

# %%
# !mkdir v5

# %%
cd v5
# Out:
# /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/v5

# %% [markdown]
# # **YoloV5s**

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO("yolov8m.yaml")  # build a new model from scratch
model = YOLO("yolov5s6u.pt")  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data="/mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/yolov5/data.yaml", epochs=50, imgsz=416)  # train the
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov5s6u.pt to 'yolov5s6u.pt'...
# 100%|██████████████████████████████████████████████████████████████████████████████| 29.6M/29.6M [00:00<00:00, 32.2MB/s]
# New https://pypi.org/project/ultralytics/8.3.7 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.6 🚀 Python-3.11.7 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# engine/trainer: task=detect, mode=train, model=yolov5s6u.pt, data=/mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/yolov5/data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      3520  ultralytics.nn.modules.conv.Conv             [3, 32, 6, 2, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     18816  ultralytics.nn.modules.block.C3              [64, 64, 1]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    115712  ultralytics.nn.modules.block.C3              [128, 128, 2]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  3    625152  ultralytics.nn.modules.block.C3              [256, 256, 3]
#   7                  -1  1    885504  ultralytics.nn.modules.conv.Conv             [256, 384, 3, 2]
#   8                  -1  1    665856  ultralytics.nn.modules.block.C3              [384, 384, 1]
#   9                  -1  1   1770496  ultralytics.nn.modules.conv.Conv             [384, 512, 3, 2]
#  10                  -1  1   1182720  ultralytics.nn.modules.block.C3              [512, 512, 1]
#  11                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  12                  -1  1    197376  ultralytics.nn.modules.conv.Conv             [512, 384, 1, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    813312  ultralytics.nn.modules.block.C3              [768, 384, 1, False]
#  16                  -1  1     98816  ultralytics.nn.modules.conv.Conv             [384, 256, 1, 1]
#  17                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  18             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    361984  ultralytics.nn.modules.block.C3              [512, 256, 1, False]
#  20                  -1  1     33024  ultralytics.nn.modules.conv.Conv             [256, 128, 1, 1]
#  21                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  22             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  1     90880  ultralytics.nn.modules.block.C3              [256, 128, 1, False]
#  24                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  25            [-1, 20]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  26                  -1  1    296448  ultralytics.nn.modules.block.C3              [256, 256, 1, False]
#  27                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  28            [-1, 16]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  29                  -1  1    715008  ultralytics.nn.modules.block.C3              [512, 384, 1, False]
#  30                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  31            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  32                  -1  1   1313792  ultralytics.nn.modules.block.C3              [768, 512, 1, False]
#  33    [23, 26, 29, 32]  1   1156648  ultralytics.nn.modules.head.Detect           [6, [128, 256, 384, 512]]
# YOLOv5s6u summary: 376 layers, 13,455,848 parameters, 13,455,832 gradients, 19.4 GFLOPs
#
# Transferred 507/611 items from pretrained weights
# Freezing layer 'model.33.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLO11n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████████████████████████████████████████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 62.6MB/s]
# AMP: checks passed ✅
# WARNING ⚠️ imgsz=[416] must be multiple of max stride 64, updating to [448]
# train: Scanning /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/yolov5/train/labels... 800 images, 0 backgr
# train: New cache created: /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/yolov5/train/labels.cache
# val: Scanning /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/yolov5/test/labels... 200 images, 0 backgroun
# val: New cache created: /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/yolov5/test/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 99 weight(decay=0.0), 108 weight(decay=0.0005), 107 bias(decay=0.0)
# Image sizes 448 train, 448 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      2.17G      1.002      2.889      1.218         34        448: 100%|██████████| 50/50 [00:13<00:00,  3.6
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201    0.00435          1      0.318      0.238
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      2.25G      1.068       2.22       1.25         37        448: 100%|██████████| 50/50 [00:11<00:00,  4.4
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.298      0.436      0.334      0.215
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50       2.2G      1.119       2.04      1.259         42        448: 100%|██████████| 50/50 [00:10<00:00,  4.7
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0
4
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.858      0.843      0.899      0.744
# 50 epochs completed in 0.186 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 27.3MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 27.3MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.6 🚀 Python-3.11.7 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# YOLOv5s6u summary (fused): 277 layers, 13,438,408 parameters, 0 gradients, 19.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:02<00
#                    all        200        201      0.858      0.843      0.899      0.744
#                  Glass         36         36      0.891      0.909      0.943      0.775
#                  Metal         31         31      0.824      0.806      0.889      0.725
#                  Paper         37         37      0.828      0.909       0.91      0.788
#                  Trash         25         25       0.71      0.783      0.813      0.599
#              cardboard         27         27      0.964      0.852      0.921      0.781
#                plastic         44         45      0.928        0.8      0.917      0.795
# Speed: 0.5ms preprocess, 4.1ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to runs/detect/train

# %%
p_yol5 = 0.858
r_yol5 = 0.843
mAP_yolo5 = 0.899

storeResults('YoloV5s6',p_yol5,r_yol5,mAP_yolo5)

# %%
# dislaying metrics for train data
from IPython.display import Image
from IPython.display import display
x = Image(filename='runs/detect/train/F1_curve.png')
y = Image(filename='runs/detect/train/PR_curve.png')
z = Image(filename='runs/detect/train/confusion_matrix.png')
display(x, y,z)

# %% [markdown]
# # **Yolov5x6**

# %%
from ultralytics import YOLO
# Load a model

# model = YOLO("yolov8m.yaml")  # build a new model from scratch
model = YOLO("yolov5x6u.pt")  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data="/mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/yolov5/data.yaml", epochs=50, imgsz=416)  # train the
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov5x6u.pt to 'yolov5x6u.pt'...
# 100%|████████████████████████████████████████████████████████████████████████████████| 297M/297M [00:12<00:00, 24.8MB/s]
# New https://pypi.org/project/ultralytics/8.3.7 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.6 🚀 Python-3.11.7 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# engine/trainer: task=detect, mode=train, model=yolov5x6u.pt, data=/mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/yolov5/data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      8800  ultralytics.nn.modules.conv.Conv             [3, 80, 6, 2, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  4    309120  ultralytics.nn.modules.block.C3              [160, 160, 4]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  8   2259200  ultralytics.nn.modules.block.C3              [320, 320, 8]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1 12  13125120  ultralytics.nn.modules.block.C3              [640, 640, 12]
#   7                  -1  1   5531520  ultralytics.nn.modules.conv.Conv             [640, 960, 3, 2]
#   8                  -1  4  11070720  ultralytics.nn.modules.block.C3              [960, 960, 4]
#   9                  -1  1  11061760  ultralytics.nn.modules.conv.Conv             [960, 1280, 3, 2]
#  10                  -1  4  19676160  ultralytics.nn.modules.block.C3              [1280, 1280, 4]
#  11                  -1  1   4099840  ultralytics.nn.modules.block.SPPF            [1280, 1280, 5]
#  12                  -1  1   1230720  ultralytics.nn.modules.conv.Conv             [1280, 960, 1, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  4  11992320  ultralytics.nn.modules.block.C3              [1920, 960, 4, False]
#  16                  -1  1    615680  ultralytics.nn.modules.conv.Conv             [960, 640, 1, 1]
#  17                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  18             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  4   5332480  ultralytics.nn.modules.block.C3              [1280, 640, 4, False]
#  20                  -1  1    205440  ultralytics.nn.modules.conv.Conv             [640, 320, 1, 1]
#  21                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  22             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  4   1335040  ultralytics.nn.modules.block.C3              [640, 320, 4, False]
#  24                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  25            [-1, 20]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  26                  -1  4   4922880  ultralytics.nn.modules.block.C3              [640, 640, 4, False]
#  27                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  28            [-1, 16]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#
hours.
# Optimizer stripped from runs/detect/train2/weights/last.pt, 288.8MB
# Optimizer stripped from runs/detect/train2/weights/best.pt, 288.8MB
#
# Validating runs/detect/train2/weights/best.pt...
# Ultralytics 8.3.6 🚀 Python-3.11.7 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# YOLOv5x6u summary (fused): 487 layers, 143,957,656 parameters, 0 gradients, 218.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:02<00
#                    all        200        201      0.782      0.696      0.805      0.654
#                  Glass         36         36      0.772      0.658      0.851       0.68
#                  Metal         31         31      0.868      0.613      0.857       0.68
#                  Paper         37         37      0.746      0.892      0.855      0.748
#                  Trash         25         25      0.605      0.552      0.577      0.418
#              cardboard         27         27       0.94      0.815      0.919      0.769
#                plastic         44         45      0.764      0.644       0.77      0.629
# Speed: 0.2ms preprocess, 5.9ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to runs/detect/train2

# %%
p_yol5 = 0.782
r_yol5 = 0.696
mAP_yolo5 = 0.805

storeResults('YoloV5x6',p_yol5,r_yol5,mAP_yolo5)

# %%
x = Image(filename='runs/detect/train2/F1_curve.png')
y = Image(filename='runs/detect/train2/PR_curve.png')
z = Image(filename='runs/detect/train2/confusion_matrix.png')
display(x, y,z)

# %% [markdown]
# # YoloV8

# %%
cd /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4
# Out:
# /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4

# %%
# !mkdir v8

# %%
cd /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/v8
# Out:
# /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/v8

# %%
# Load a model
# model = YOLO("yolov8m.yaml")  # build a new model from scratch
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data="/mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/yolov8/data.yaml", epochs=50, imgsz=416)  # train the
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████████████████████████████████████████████████████████████████████████| 6.25M/6.25M [00:00<00:00, 65.7MB/s]
# New https://pypi.org/project/ultralytics/8.3.7 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.6 🚀 Python-3.11.7 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/yolov8/data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    431842  ultralytics.nn.modules.head.Detect           [6, [64, 128, 256]]
# Model summary: 249 layers, 2,691,378 parameters, 2,691,362 gradients, 6.9 GFLOPs
#
# Transferred 313/391 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLO11n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████████████████████████████████████████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 66.9MB/s]
# AMP: checks passed ✅
# train: Scanning /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/yolov8/train/labels... 800 images, 0 backgr
# train: New cache created: /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/yolov8/train/labels.cache
# val: Scanning /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/yolov8/test/labels... 200 images, 0 backgroun
# val: New cache created: /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/yolov8/test/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 63 weight(decay=0.0), 70 weight(decay=0.0005), 69 bias(decay=0.0)
# Image sizes 416 train, 416 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      3.97G     0.8933      3.151       1.24         34        416: 100%|██████████| 50/50 [00:11<00:00,  4.3
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201    0.00774      0.985      0.214      0.155
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      1.14G     0.9588      2.568      1.275         37        416: 100%|██████████| 50/50 [00:09<00:00,  5.0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.445       0.15      0.306      0.195
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      1.15G      1.013      2.032      1.301         42        416: 100%|██████████| 50/50 [00:09<00:00,  5.5
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.297      0.535      0.385      0.243
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      1.15G      1.001      1.762      1.276         41        416: 100%|██████████| 50/50 [00:08<00:00,  5.6
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.353      0.614      0.402      0.244
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      1.15G     0.9869      1.655       1.27         48        416: 100%|██████████| 50/50 [00:08<00:00,  5.7
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.482      0.535      0.477      0.322
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      1.15G     0.9951      1.533      1.257         41        416: 100%|██████████| 50/50 [00:08<00:00,  5.6
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.623      0.613      0.614      0.401
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      1.15G      0.979      1.506      1.253         34        416: 100%|██████████| 50/50 [00:08<00:00,  5.8
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.556      0.618      0.602      0.429
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      1.15G     0.9124      1.413      1.204         47        416: 100%|██████████| 50/50 [00:09<00:00,  5.4
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.511      0.751      0.686      0.505
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      1.15G     0.9053      1.323      1.197         45        416: 100%|██████████| 50/50 [00:09<00:00,  5.5
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.475      0.668      0.679      0.514
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      1.15G      0.903      1.319      1.208         33        416: 100%|██████████| 50/50 [00:09<00:00,  5.2
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0
7
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.856      0.833      0.874      0.697
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      1.15G     0.7445     0.7827      1.112         50        416: 100%|██████████| 50/50 [00:07<00:00,  6.2
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.815      0.802       0.88      0.707
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      1.15G     0.7308     0.7436      1.105         36        416: 100%|██████████| 50/50 [00:08<00:00,  6.0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.866      0.777        0.9       0.72
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      1.15G     0.7289     0.7238      1.105         40        416: 100%|██████████| 50/50 [00:07<00:00,  6.3
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.792      0.821      0.894      0.723
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      1.15G     0.7224     0.7057      1.103         48        416: 100%|██████████| 50/50 [00:08<00:00,  5.9
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.859      0.816      0.905      0.729
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      1.15G     0.7016      0.699      1.084         43        416: 100%|██████████| 50/50 [00:08<00:00,  5.8
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.809      0.867      0.887      0.712
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      1.15G     0.7175     0.6954      1.096         42        416: 100%|██████████| 50/50 [00:09<00:00,  5.4
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.867      0.824      0.908      0.739
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      1.15G     0.5828      0.672      1.068         16        416: 100%|██████████| 50/50 [00:09<00:00,  5.3
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.815      0.839      0.907      0.728
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      1.15G     0.5626     0.5632      1.063         16        416: 100%|██████████| 50/50 [00:12<00:00,  4.1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:02<00
#                    all        200        201      0.804       0.88      0.905      0.722
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      1.15G     0.5467     0.5497      1.045         17        416: 100%|██████████| 50/50 [00:11<00:00,  4.2
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.843      0.823      0.899       0.72
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      1.15G     0.5455     0.5463      1.051         16        416: 100%|██████████| 50/50 [00:08<00:00,  5.8
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.857       0.82      0.914      0.744
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      1.15G     0.5366     0.5088      1.046         16        416: 100%|██████████| 50/50 [00:08<00:00,  5.7
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.844      0.836      0.916      0.742
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      1.15G      0.524     0.4844      1.019         16        416: 100%|██████████| 50/50 [00:09<00:00,  5.5
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.916      0.807      0.927      0.757
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      1.15G     0.5134     0.4605      1.023         17        416: 100%|██████████| 50/50 [00:11<00:00,  4.3
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:02<00
#                    all        200        201      0.858      0.859      0.928      0.756
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      1.15G     0.5082      0.454      1.021         16        416: 100%|██████████| 50/50 [00:12<00:00,  4.1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.887      0.866       0.92      0.749
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      1.15G     0.4883     0.4592       1.02         17        416: 100%|██████████| 50/50 [00:12<00:00,  4.1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201       0.86      0.858      0.923      0.757
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      1.15G     0.4965     0.4387      1.011         16        416: 100%|██████████| 50/50 [00:10<00:00,  4.6
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.873      0.853      0.927       0.76
# 50 epochs completed in 0.196 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 5.6MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 5.6MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.6 🚀 Python-3.11.7 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# Model summary (fused): 186 layers, 2,685,538 parameters, 0 gradients, 6.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.873      0.853      0.927       0.76
#                  Glass         36         36      0.897      0.833      0.953      0.785
#                  Metal         31         31      0.866      0.774      0.905      0.736
#                  Paper         37         37      0.799      0.892      0.879      0.749
#                  Trash         25         25      0.814      0.875      0.927      0.682
#              cardboard         27         27      0.961      0.922       0.95      0.802
#                plastic         44         45      0.898      0.822      0.946      0.806
# Speed: 0.5ms preprocess, 2.4ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to runs/detect/train

# %%
p_yol5 = 0.873
r_yol5 = 0.853
mAP_yolo5 = 0.927

storeResults('YoloV8',p_yol5,r_yol5,mAP_yolo5)

# %%
x = Image(filename='runs/detect/train/F1_curve.png')
y = Image(filename='runs/detect/train/PR_curve.png')
z = Image(filename='runs/detect/train/confusion_matrix.png')
display(x, y,z)

# %% [markdown]
# # **Yolov9**

# %%
cd /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4
# Out:
# /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4

# %%
# !mkdir v9

# %%
cd v9
# Out:
# /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/v9

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO("yolov8m.yaml")  # build a new model from scratch
model = YOLO("yolov9c.pt")

# Use the model
results = model.train(data="/mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/yolov9/data.yaml", epochs=50, imgsz=416)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.3.7 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.6 🚀 Python-3.11.7 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# engine/trainer: task=detect, mode=train, model=yolov9c.pt, data=/mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/yolov9/data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    212864  ultralytics.nn.modules.block.RepNCSPELAN4    [128, 256, 128, 64, 1]
#   3                  -1  1    164352  ultralytics.nn.modules.block.ADown           [256, 256]
#   4                  -1  1    847616  ultralytics.nn.modules.block.RepNCSPELAN4    [256, 512, 256, 128, 1]
#   5                  -1  1    656384  ultralytics.nn.modules.block.ADown           [512, 512]
#   6                  -1  1   2857472  ultralytics.nn.modules.block.RepNCSPELAN4    [512, 512, 512, 256, 1]
#   7                  -1  1    656384  ultralytics.nn.modules.block.ADown           [512, 512]
#   8                  -1  1   2857472  ultralytics.nn.modules.block.RepNCSPELAN4    [512, 512, 512, 256, 1]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPELAN         [512, 512, 256]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1   3119616  ultralytics.nn.modules.block.RepNCSPELAN4    [1024, 512, 512, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    912640  ultralytics.nn.modules.block.RepNCSPELAN4    [1024, 256, 256, 128, 1]
#  16                  -1  1    164352  ultralytics.nn.modules.block.ADown           [256, 256]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1   2988544  ultralytics.nn.modules.block.RepNCSPELAN4    [768, 512, 512, 256, 1]
#  19                  -1  1    656384  ultralytics.nn.modules.block.ADown           [512, 512]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   3119616  ultralytics.nn.modules.block.RepNCSPELAN4    [1024, 512, 512, 256, 1]
#  22        [15, 18, 21]  1   1415650  ultralytics.nn.modules.head.Detect           [6, [256, 512, 512]]
# YOLOv9c summary: 642 layers, 21,362,082 parameters, 21,362,066 gradients, 84.1 GFLOPs
#
# Transferred 895/973 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLO11n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████████████████████████████████████████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 67.1MB/s]
# AMP: checks passed ✅
# train: Scanning /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/yolov9/train/labels... 800 images, 0 backgr
# train: New cache created: /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/yolov9/train/labels.cache
# val: Scanning /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/yolov9/test/labels... 200 images, 0 backgroun
# val: New cache created: /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/4/yolov9/test/labels.cache
# Plotting labels to runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 160 weight(decay=0.0), 167 weight(decay=0.0005), 166 bias(decay=0.0)
# Image sizes 416 train, 416 val
# Using 8 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      5.05G      1.036      2.792      1.409         34        416: 100%|██████████| 50/50 [00:19<00:00,  2.5
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201    0.00353      0.977      0.313      0.181
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      5.16G      1.173      2.116      1.447         37        416: 100%|██████████| 50/50 [00:20<00:00,  2.4
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201       0.12      0.228      0.119     0.0629
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      5.17G      1.214      1.979      1.459         42        416: 100%|██████████| 50/50 [00:17<00:00,  2.9
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.223      0.173      0.051     0.0338
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      5.16G      1.174       1.83      1.412         41        416: 100%|██████████| 50/50 [00:17<00:00,  2.8
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.117      0.267      0.129     0.0476
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      5.16G       1.13      1.725      1.361         48        416: 100%|██████████| 50/50 [00:16<00:00,  3.0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.143      0.485      0.178      0.115
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      5.15G      1.119      1.593      1.345         41        416: 100%|██████████| 50/50 [00:15<00:00,  3.2
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.348      0.546        0.4      0.234
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      5.15G      1.111      1.549       1.34         34        416: 100%|██████████| 50/50 [00:15<00:00,  3.2
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201       0.48      0.519      0.426      0.275
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      5.16G      1.047      1.471      1.295         47        416: 100%|██████████| 50/50 [00:16<00:00,  3.0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.299        0.4      0.306       0.18
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      5.16G       1.03      1.375      1.274         45        416: 100%|██████████| 50/50 [00:15<00:00,  3.2
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.327      0.574      0.456      0.283
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      5.15G      1.016      1.416      1.277         33        416: 100%|██████████| 50/50 [00:15<00:00,  3.2
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.507       0.64      0.614      0.468
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      5.15G     0.9979      1.352      1.265         49        416: 100%|██████████| 50/50 [00:15<00:00,  3.2
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.484      0.693      0.578      0.424
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      5.15G      1.007      1.283      1.284         45        416: 100%|██████████| 50/50 [00:15<00:00,  3.2
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.561      0.693      0.634      0.434
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      5.15G     0.9549      1.225       1.23         33        416: 100%|██████████| 50/50 [00:15<00:00,  3.1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.648      0.645      0.701      0.546
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      5.15G     0.9388      1.159      1.229         39        416: 100%|██████████| 50/50 [00:18<00:00,  2.7
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.503       0.72      0.695      0.527
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      5.16G     0.9551      1.181      1.238         43        416: 100%|██████████| 50/50 [00:15<00:00,  3.1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.545      0.598      0.611      0.458
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      5.15G     0.9532      1.176      1.235         36        416: 100%|██████████| 50/50 [00:15<00:00,  3.2
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.508      0.631      0.619      0.478
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      5
9
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.852      0.782       0.91      0.744
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      5.15G      0.594     0.5687      1.096         16        416: 100%|██████████| 50/50 [00:16<00:00,  3.0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.823      0.858      0.908      0.742
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      5.16G     0.5847     0.4975      1.075         16        416: 100%|██████████| 50/50 [00:15<00:00,  3.2
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.835      0.821      0.895       0.74
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      5.15G     0.5795     0.4757      1.082         17        416: 100%|██████████| 50/50 [00:15<00:00,  3.3
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.862      0.791      0.904      0.756
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      5.15G     0.5687     0.4603      1.074         16        416: 100%|██████████| 50/50 [00:15<00:00,  3.1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.871      0.827      0.916       0.76
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      5.15G     0.5519     0.4397      1.076         17        416: 100%|██████████| 50/50 [00:15<00:00,  3.1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.864       0.82      0.918      0.759
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      5.16G     0.5526     0.4328      1.062         16        416: 100%|██████████| 50/50 [00:16<00:00,  3.0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.856      0.853      0.923      0.763
# 50 epochs completed in 0.306 hours.
# Optimizer stripped from runs/detect/train2/weights/last.pt, 43.2MB
# Optimizer stripped from runs/detect/train2/weights/best.pt, 43.2MB
#
# Validating runs/detect/train2/weights/best.pt...
# Ultralytics 8.3.6 🚀 Python-3.11.7 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# YOLOv9c summary (fused): 402 layers, 21,150,050 parameters, 0 gradients, 82.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00
#                    all        200        201      0.856      0.852      0.923      0.764
#                  Glass         36         36      0.906      0.861      0.928      0.769
#                  Metal         31         31       0.93      0.859      0.946      0.783
#                  Paper         37         37      0.727      0.946      0.928      0.794
#                  Trash         25         25      0.827        0.8      0.885      0.683
#              cardboard         27         27      0.825      0.874       0.91      0.766
#                plastic         44         45      0.921      0.775      0.938      0.788
# Speed: 0.2ms preprocess, 4.4ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to runs/detect/train2

# %%
p_yol5 = 0.853
r_yol5 = 0.852
mAP_yolo5 = 0.923

storeResults('YoloV9',p_yol5,r_yol5,mAP_yolo5)

# %%
x = Image(filename='runs/detect/train2/F1_curve.png')
y = Image(filename='runs/detect/train2/PR_curve.png')
z = Image(filename='runs/detect/train2/confusion_matrix.png')
display(x, y,z)

# %% [markdown]
# # Comparison

# %%
#creating dataframe
import pandas as pd
result = pd.DataFrame({ 'ML Model' : ML_Model,

                       'Precision': precision,
                       'Recall'   : recall,
                       'mAP' : mAP,


                      })

# %%
result
# Out:
#    ML Model  Precision  Recall    mAP
# 0  YoloV5s6      0.858   0.843  0.899
# 1  YoloV5x6      0.782   0.696  0.805
# 2    YoloV8      0.873   0.853  0.927
# 3    YoloV9      0.853   0.852  0.923

# %% [markdown]
# # Graph

# %%
import numpy as np

# %%
classifier = ML_Model
y_pos = np.arange(len(classifier))

# %% [markdown]
# # Precision

# %%
import matplotlib.pyplot as plt2
plt2.barh(y_pos, precision, align='center', alpha=0.5,color='red')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Precision Score')
plt2.title('Classification Performance')
plt2.show()

# %% [markdown]
# # Recall

# %%
import matplotlib.pyplot as plt2
plt2.barh(y_pos, recall, align='center', alpha=0.5,color='yellow')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Recall Score')
plt2.title('Classification Performance')
plt2.show()

# %% [markdown]
# # mAP

# %%
import matplotlib.pyplot as plt2
plt2.barh(y_pos, mAP, align='center', alpha=0.5,color='navy')
plt2.yticks(y_pos, classifier)
plt2.xlabel('mAP')
plt2.title('Classification Performance')
plt2.show()
